# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm

# %%
BASE_URL = "https://www.ttmg.org/insidersguide/new-york-mta-bus-roster/new-york-mta-bus-roster-depot/"
html = requests.get(BASE_URL).text
soup = BeautifulSoup(html, "html5lib")

# %%
divisions = list()
for division in soup.findAll("span", {"class": "mw-headline"}):
    divisions.append(division.getText().strip())
print(divisions)
# Out:
# ['Bronx Division', 'Manhattan Division', 'Queens Division', 'Brooklyn Division', 'Staten Island Division']

# %%
bronx_df = manhattan_df = queens_df = brooklyn_df = si_df = pd.DataFrame()
bronx, manhattan, queens, brooklyn, si = soup.findAll("table", {"style": "border-spacing: 2px; border: 3px solid white; font-size: 90%; width: 100%"})
boroughs = {"Bronx": bronx, "Manhattan": manhattan, "Queens": queens, "Brooklyn": brooklyn, "Staten Island": si}

# %%
import re

def save_depot_information(boroughs):
    df = pd.DataFrame(columns=["Borough", "Address", "Total buses"])
    for borough_name in boroughs:
        borough = boroughs[borough_name]
        for facility in borough.findAll("tr", {"style": "background:#000000; color:#FFFFFF", "align": "left"}):
            data = facility.find("td").getText()
            information = data.split("\n")
            name, address, total_buses = information[1], re.sub(r"\([^)]*\), ", "", information[2]), int(information[3][information[3].rfind(" ") + 1:])
            df.loc[name, ["Borough", "Address", "Total buses"]] = borough_name, address, total_buses
    df.index.name = "Depot"
    return df

# %%
depots_df = save_depot_information(boroughs)
depots_df.head()
# Out:
#                         Borough  \
# Depot
#  Eastchester Depot (EC)   Bronx
#  Gun Hill Depot (GH)      Bronx
#  Kingsbridge Depot (KB)   Bronx
#  West Farms Depot (WF)    Bronx
#  Yonkers Depot (YO)       Bronx
#
#                                                                    Address  \
# Depot
#  Eastchester Depot (EC)                 3320 Tillotson Av, Bronx, NY 10475
#  Gun Hill Depot (GH)                       1910 Bartow Av, Bronx, NY 10469
#  Kingsbridge Depot (KB)                   4065 10th Av, New York, NY 10034
#  West Farms Depot (WF)   Bronx Division Headquarters, 1100 E 177th St, ...
#  Yonkers Depot (YO)                       59 Babcock Pl, Yonkers, NY 10701
#
#                         Total buses
# Depot
#  Eastchester Depot (EC)         142
#  Gun Hill Depot (GH)            284
#  Kingsbridge Depot (KB)         272
#  West Farms Depot (WF)          321
#  Yonkers Depot (YO)              84

# %%
depots_df.to_csv("../../data/depot_data/depots.csv")

# %%
DEPOT_URL = "https://sites.google.com/site/mtanewyorkcitybusroster/new-york-city-bus-roster"
depot_html = requests.get(DEPOT_URL).text
depot_soup = BeautifulSoup(depot_html, "html5lib")

# %%
depot_list = depot_soup.find("ul", {"role": "navigation", "class": "has-expander"})
all_urls = [a["href"] for a in depot_list.findAll("a") if a.has_attr("href")]
print(len(all_urls))
# Out:
# 32

# %%
depot_urls = [url for url in all_urls if re.match(r"/site/mtanewyorkcitybusroster/new-york-city-bus-roster/.*", url)]
del depot_urls[0] # 126 Depot is closed
print(len(depot_urls))
# Out:
# 27

# %%
def process_depot_urls(depot_urls):
    df = pd.DataFrame(columns=["Make", "Model", "Year", "Depot"])
    for depot_url in tqdm(depot_urls):    
        html = requests.get(f"https://sites.google.com{depot_url}").text
        soup = BeautifulSoup(html, "html5lib")
        depot_name = get_depot_name(soup)
        tables = get_tables(soup)
        for table in tables:
            for row in table.findAll("tr"):
                row_info = process_row(row)
                make_model, year, ids = row_info[0], row_info[-3], row_info[-2]
                make, model = make_model.split("\n", 1)
                make, model = re.sub(r"\s+", " ", make), re.sub(r"\s+", " ", model)
                for year, bus_id in zip(year.split("\n"), ids.split("\n")):
                    for ran in bus_id.split(","):
                        ran = re.sub(r"\s+", "", ran)
                        try:
                            nums = nums_from_range(ran)
                        except:
                            continue
                        for num in nums:
                            df.loc[num, :] = make, model, year, depot_name
    df.index.name = "ID"
    return df

def get_depot_name(soup):
    return soup.find("span", {"id": "sites-page-title"}).getText()

def get_tables(soup):
    site_main = soup.find("div", {"id": "sites-canvas-main", "class": "sites-canvas-main"})
    return site_main.findAll("table", {"border": "1", "bordercolor": "#888", "cellspacing": "0"})

def process_row(row):
    info = list()
    for col in row.findAll("td"):
        if col.has_attr("style") and re.match("text-.*", col["style"]):
            info.append(col.getText(separator="\n"))
    return info

def nums_from_range(ran):
    endpoints = ran.split("-")
    if len(endpoints) == 1:
        return [int(endpoints[0])]
    beg, end = endpoints
    return [num for num in range(int(beg), int(end) + 1)]

# %%
depot_url = depot_urls[14]
html = requests.get(f"https://sites.google.com{depot_url}").text
soup = BeautifulSoup(html, "html5lib")
depot_name = get_depot_name(soup)
tables = get_tables(soup)
for table in tables:
    for row in table.findAll("tr"):
        row_info = process_row(row)
        make_model, year, ids = row_info[0], row_info[-3], row_info[-2]
        make, model = make_model.split("\n", 1)
        make, model = re.sub(r"\s+", " ", make), re.sub(r"\s+", " ", model)
        for year, bus_id in zip(year.split("\n"), ids.split("\n")):
            for ran in bus_id.split(","):
                ran = re.sub(r"\s+", "", ran)
                try:
                    nums = nums_from_range(ran)
                except:
                    continue
                for num in nums:
                    print(num, depot_name, make, model, int(year))
# Out:
# 1200 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2009
# 1202 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1204 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1206 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1207 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1208 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1209 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1210 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1211 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1212 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1213 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1214 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1215 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1216 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1248 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1249 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1250 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1251 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1252 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1253 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1254 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1255 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1256 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1258 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1259 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1260 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1261 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1263 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1264 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1265 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1266 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1267 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1268 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1269 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1270 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1271 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1277 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1285 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1287 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1288 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 1289 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2010
# 5787 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 5788 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 5789 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 5793 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 5794 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 5796 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 5799 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 5800 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 5802 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 5803 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 5805 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 5811 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 5813 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 5814 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 5815 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 5818 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 5819 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 5822 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 5823 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 5831 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 5832 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 5833 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 5842 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 5843 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 5844 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 5845 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 5847 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 5848 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 5849 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 5850 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 5851 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 5855 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North Ameirca Nova Bus LFS Articulated 2011
# 4746 Kingsbridge Bus Depot (MaBSTOA) New Flyer Industries XD60 Xcelsior Articulated 2012
# 4747 Kingsbridge Bus Depot (MaBSTOA) New Flyer Industries XD60 Xcelsior Articulated 2012
# 4748 Kingsbridge Bus Depot (MaBSTOA) New Flyer Industries XD60 Xcelsior Articulated 2012
# 4749 Kingsbridge Bus Depot (MaBSTOA) New Flyer Industries XD60 Xcelsior Articulated 2012
# 4750 Kingsbridge Bus Depot (MaBSTOA) New Flyer Industries XD60 Xcelsior Articulated 2012
# 4751 Kingsbridge Bus Depot (MaBSTOA) New Flyer Industries XD60 Xcelsior Articulated 2012
# 4752 Kingsbridge Bus Depot (MaBSTOA) New Flyer Industries XD60 Xcelsior Articulated 2012
# 4753 Kingsbridge Bus Depot (MaBSTOA) New Flyer Industries XD60 Xcelsior Articulated 2012
# 5439 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus Articulated 2016
# 5441 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus Articulated 2016
# 4365 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4366 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4367 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4368 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4369 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4370 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4371 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4372 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4373 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4374 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4375 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4376 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4377 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4378 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4379 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4380 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4381 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4382 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4383 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4384 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4385 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4386 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4387 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4388 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4389 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4390 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4391 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4405 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4421 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4424 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4454 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4580 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4581 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4582 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4583 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4584 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4585 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4586 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 4587 Kingsbridge Bus Depot (MaBSTOA) Daimler Buses Orion VII Next Generation Hybrid Low Floor 2009
# 8359 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2015
# 8360 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2015
# 8361 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2015
# 8362 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2015
# 8363 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2015
# 8364 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2015
# 8365 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2015
# 8366 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2015
# 8367 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2015
# 8368 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2015
# 8369 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2015
# 8370 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2015
# 8371 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2015
# 8372 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2015
# 8373 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2015
# 8374 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2016
# 8375 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2016
# 8376 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2016
# 8377 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2016
# 8378 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2016
# 8379 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2016
# 8380 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2016
# 8381 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2016
# 8382 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2016
# 8383 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2016
# 8384 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2016
# 8385 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2016
# 8386 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2016
# 8387 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2016
# 8388 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2016
# 8389 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2016
# 8390 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2016
# 8391 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2016
# 8392 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2016
# 8393 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2016
# 8394 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2016
# 8395 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2016
# 8396 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2016
# 8397 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2016
# 8398 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS 2016
# 8543 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8544 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8545 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8546 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8547 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8548 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8549 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8550 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8551 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8552 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8553 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8554 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8555 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8556 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8557 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8558 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8559 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8560 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8561 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8562 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8563 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8564 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8565 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8566 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8567 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8568 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8569 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8570 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8571 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8572 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8664 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8665 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8666 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8667 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8668 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8669 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8670 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8671 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8672 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8673 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8674 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8675 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8676 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8677 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8678 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8679 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8680 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8681 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8682 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8683 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8684 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8685 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8686 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8687 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8688 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8689 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8690 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8691 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8692 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019
# 8693 Kingsbridge Bus Depot (MaBSTOA) Volvo Group North America Nova Bus LFS SmartBus 2019

# %%
buses_df = process_depot_urls(depot_urls)
buses_df.head()
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]
#
#
#   4%|▎         | 1/27 [00:00<00:23,  1.12it/s]
#
#
#   7%|▋         | 2/27 [00:02<00:25,  1.04s/it]
#
#
#  11%|█         | 3/27 [00:03<00:23,  1.02it/s]
#
#
#  15%|█▍        | 4/27 [00:03<00:21,  1.06it/s]
#
#
#  19%|█▊        | 5/27 [00:04<00:20,  1.05it/s]
#
#
#  22%|██▏       | 6/27 [00:05<00:19,  1.08it/s]
#
#
#  26%|██▌       | 7/27 [00:06<00:17,  1.13it/s]
#
#
#  30%|██▉       | 8/27 [00:07<00:17,  1.09it/s]
#
#
#  33%|███▎      | 9/27 [00:08<00:16,  1.10it/s]
#
#
#  37%|███▋      | 10/27 [00:09<00:15,  1.10it/s]
#
#
#  41%|████      | 11/27 [00:10<00:15,  1.06it/s]
#
#
#  44%|████▍     | 12/27 [00:11<00:13,  1.09it/s]
#
#
#  48%|████▊     | 13/27 [00:12<00:13,  1.08it/s]
#
#
#  52%|█████▏    | 14/27 [00:13<00:11,  1.12it/s]
#
#
#  56%|█████▌    | 15/27 [00:13<00:10,  1.12it/s]
#
#
#  59%|█████▉    | 16/27 [00:14<00:10,  1.08it/s]
#
#
#  63%|██████▎   | 17/27 [00:15<00:09,  1.04it/s]
#
#
#  67%|██████▋   | 18/27 [00:16<00:08,  1.05it/s]
#
#
#  70%|███████   | 19/27 [00:17<00:07,  1.05it/s]
#
#
#  74%|███████▍  | 20/27 [00:18<00:06,  1.08it/s]
#
#
#  78%|███████▊  | 21/27 [00:19<00:05,  1.06it/s]
#
#
#  81%|████████▏ | 22/27 [00:20<00:04,  1.10it/s]
#
#
#  85%|████████▌ | 23/27 [00:21<00:03,  1.16it/s]
#
#
#  89%|████████▉ | 24/27 [00:22<00:02,  1.09it/s]
#
#
#  93%|█████████▎| 25/27 [00:23<00:01,  1.03it/s]
#
#
#  96%|█████████▋| 26/27 [00:24<00:00,  1.11it/s]
#
#
# 100%|██████████| 27/27 [00:25<00:00,  1.08it/s]
#                Make                                       Model  Year  \
# ID
# 3516  Daimler Buses  Orion VII 2nd Generation+ Hybrid Low Floor  2006
# 3517  Daimler Buses  Orion VII 2nd Generation+ Hybrid Low Floor  2006
# 3518  Daimler Buses  Orion VII 2nd Generation+ Hybrid Low Floor  2006
# 3519  Daimler Buses  Orion VII 2nd Generation+ Hybrid Low Floor  2006
# 3520  Daimler Buses  Orion VII 2nd Generation+ Hybrid Low Floor  2006
#
#                              Depot
# ID
# 3516  Baisley Park Depot (MTA Bus)
# 3517  Baisley Park Depot (MTA Bus)
# 3518  Baisley Park Depot (MTA Bus)
# 3519  Baisley Park Depot (MTA Bus)
# 3520  Baisley Park Depot (MTA Bus)

# %%
BUSES_ID_FILENAME = "../../data/depot_data/buses_id_data.csv"
buses_df.to_csv(BUSES_ID_FILENAME)
