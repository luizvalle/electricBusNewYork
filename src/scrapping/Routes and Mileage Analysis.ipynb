# %% [markdown]
# # Routes and Mileage

# %% [markdown]
# ## Extract routes and endpoints from static MTA data

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
from tqdm import tqdm
import numpy as np

# %%
routes = pd.Series([], dtype=str)
endpoints_1 = pd.Series([], dtype=str)
endpoints_2 = pd.Series([], dtype=str)

boroughs = ["google_transit_bronx", "google_transit_brooklyn", "google_transit_manhattan", "google_transit_queens",
           "google_transit_staten_island"]

for borough in boroughs:
    filename = f"mta_bus_data/{borough}/routes.txt"
    df = pd.read_csv(filename)
    routes = routes.append(df["route_short_name"], ignore_index=True)
    start_finish_df = df["route_long_name"].str.split(" - ", expand=True)
    endpoints_1 = endpoints_1.append(start_finish_df[0], ignore_index=True)
    endpoints_2 = endpoints_2.append(start_finish_df[1], ignore_index=True)

routes_df = pd.DataFrame()
routes_df["Route"] = routes
routes_df["End point 1"] = endpoints_1
routes_df["End point 2"] = endpoints_2
routes_df = routes_df.set_index("Route")

# %%
routes_df.head()
# Out:
#           End point 1                End point 2
# Route
# Bx1         Riverdale                 Mott Haven
# Bx10        Riverdale                    Norwood
# Bx11      Parkchester  Southern Blvd & GW Bridge
# Bx12      Pelham Pkwy                 Fordham Rd
# Bx12-SBS  Pelham Pkwy                 Fordham Rd

# %% [markdown]
# ## Extract Mileage from bus route profiles

# %%
profiles_df = pd.read_csv("mta_bus_data/bus_route_profiles.csv")
profiles_df.set_index("Route", inplace=True)
profiles_df.index = profiles_df.index.str.replace(" SBS", "-SBS").str.lower().str.rstrip("*")
profiles_df.head(20)
# Out:
#          Average Weekday Ridership, 2011 Average Weekday Ridership, 2016  \
# Route
# bx1                               38,891                          36,487
# bx2                               38,891                          36,487
# bx3                               15,800                          14,921
# bx4                               12,141                          11,411
# bx4a                              12,141                          11,411
# bx5                               12,186                          11,194
# bx6                               22,146                          23,800
# bx7                               14,771                          13,720
# bx8                                6,763                           7,282
# bx9                               26,868                          27,175
# bx10                              10,500                          11,266
# bx11                              13,312                          14,269
# bx12                              45,436                          48,124
# bx12-sbs                          45,436                          48,124
# bx13                              10,437                          12,094
# bx15                              20,096                          28,156
# bx16                               7,566                           8,239
# bx17                              10,075                          10,219
# bx18                               1,720                           1,920
# bx19                              30,712                          29,378
#
#          Ridership Change, 2011-2016 On-Time Performance 2016  \
# Route
# bx1                              -6%                      69%
# bx2                              -6%                      60%
# bx3                              -6%                      65%
# bx4                              -6%                      63%
# bx4a                             -6%                      59%
# bx5                              -8%                      69%
# bx6                               7%                      66%
# bx7                              -7%                      72%
# bx8                               8%                      69%
# bx9                               1%                      67%
# bx10                              7%                      72%
# bx11                              7%                      61%
# bx12                              6%                      66%
# bx12-sbs                          6%                      70%
# bx13                             16%                      69%
# bx15                             40%                      48%
# bx16                              9%                      71%
# bx17                              1%                      56%
# bx18                             12%                      53%
# bx19                             -4%                      58%
#
#          Wait Assessment 2016  Average Speed (mph)  \
# Route
# bx1                       85%                  7.0
# bx2                       75%                  6.0
# bx3                       79%                  7.0
# bx4                       79%                  6.0
# bx4a                      77%                  6.0
# bx5                       82%                  8.0
# bx6                       81%                  6.0
# bx7                       82%                  7.0
# bx8                       82%                  8.0
# bx9                       81%                  6.0
# bx10                      84%                  8.0
# bx11                      78%                  5.0
# bx12                      82%                  7.0
# bx12-sbs                  83%                 10.0
# bx13                      83%                  6.0
# bx15                      71%                  5.0
# bx16                      82%                  8.0
# bx17                      74%                  6.0
# bx18                      76%                  7.0
# bx19                      76%                  5.0
#
#           Length of Route (in miles)  \
# Route
# bx1                              8.8
# bx2                              8.0
# bx3                              4.5
# bx4                              4.7
# bx4a                             4.9
# bx5                              7.7
# bx6                              5.8
# bx7                              6.0
# bx8                              8.7
# bx9                              6.4
# bx10                             7.4
# bx11                             4.9
# bx12                             8.1
# bx12-sbs                         7.6
# bx13                             4.1
# bx15                             7.6
# bx16                             7.4
# bx17                             5.7
# bx18                             2.4
# bx19                             6.8
#
#           Frequency during AM Rush, Buses per Hour (7:30am to 8:30am)  \
# Route
# bx1                                                     7.0
# bx2                                                     7.0
# bx3                                                    11.0
# bx4                                                     5.0
# bx4a                                                    6.0
# bx5                                                    10.0
# bx6                                                    17.0
# bx7                                                    10.0
# bx8                                                     8.0
# bx9                                                    15.0
# bx10                                                   13.0
# bx11                                                   13.0
# bx12                                                    8.0
# bx12-sbs                                               15.0
# bx13                                                   15.0
# bx15                                                   19.0
# bx16                                                   11.0
# bx17                                                   10.0
# bx18                                                    5.0
# bx19                                                   11.0
#
#           Frequency in the Evening, Buses per Hour (8:30pm to 10:30pm)  \
# Route
# bx1                                                     4.0
# bx2                                                     3.0
# bx3                                                     7.0
# bx4                                                     3.0
# bx4a                                                    3.0
# bx5                                                     6.0
# bx6                                                     9.0
# bx7                                                     5.0
# bx8                                                     2.0
# bx9                                                     8.0
# bx10                                                    5.0
# bx11                                                    4.0
# bx12                                                    6.0
# bx12-sbs                                                6.0
# bx13                                                    8.0
# bx15                                                    6.0
# bx16                                                    3.0
# bx17                                                    4.0
# bx18                                                    3.0
# bx19                                                    6.0
#
#           # of Stops along Route  ... Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# Route                             ...
# bx1                         47.0  ...         NaN          NaN          NaN
# bx2                         50.0  ...         NaN          NaN          NaN
# bx3                         28.0  ...         NaN          NaN          NaN
# bx4                         32.0  ...         NaN          NaN          NaN
# bx4a                        35.0  ...         NaN          NaN          NaN
# bx5                         36.0  ...         NaN          NaN          NaN
# bx6                         32.0  ...         NaN          NaN          NaN
# bx7                         43.0  ...         NaN          NaN          NaN
# bx8                         55.0  ...         NaN          NaN          NaN
# bx9                         37.0  ...         NaN          NaN          NaN
# bx10                        41.0  ...         NaN          NaN          NaN
# bx11                        35.0  ...         NaN          NaN          NaN
# bx12                        32.0  ...         NaN          NaN          NaN
# bx12-sbs                    16.0  ...         NaN          NaN          NaN
# bx13                        26.0  ...         NaN          NaN          NaN
# bx15                        45.0  ...         NaN          NaN          NaN
# bx16                        37.0  ...         NaN          NaN          NaN
# bx17                        37.0  ...         NaN          NaN          NaN
# bx18                        17.0  ...         NaN          NaN          NaN
# bx19                        44.0  ...         NaN          NaN          NaN
#
#           Unnamed: 20 Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  \
# Route
# bx1               NaN         NaN          NaN          NaN          NaN
# bx2               NaN         NaN          NaN          NaN          NaN
# bx3               NaN         NaN          NaN          NaN          NaN
# bx4               NaN         NaN          NaN          NaN          NaN
# bx4a              NaN         NaN          NaN          NaN          NaN
# bx5               NaN         NaN          NaN          NaN          NaN
# bx6               NaN         NaN          NaN          NaN          NaN
# bx7               NaN         NaN          NaN          NaN          NaN
# bx8               NaN         NaN          NaN          NaN          NaN
# bx9               NaN         NaN          NaN          NaN          NaN
# bx10              NaN         NaN          NaN          NaN          NaN
# bx11              NaN         NaN          NaN          NaN          NaN
# bx12              NaN         NaN          NaN          NaN          NaN
# bx12-sbs          NaN         NaN          NaN          NaN          NaN
# bx13              NaN         NaN          NaN          NaN          NaN
# bx15              NaN         NaN          NaN          NaN          NaN
# bx16              NaN         NaN          NaN          NaN          NaN
# bx17              NaN         NaN          NaN          NaN          NaN
# bx18              NaN         NaN          NaN          NaN          NaN
# bx19              NaN         NaN          NaN          NaN          NaN
#
#           Unnamed: 25 Unnamed: 26
# Route
# bx1               NaN         NaN
# bx2               NaN         NaN
# bx3               NaN         NaN
# bx4               NaN         NaN
# bx4a              NaN         NaN
# bx5               NaN         NaN
# bx6               NaN         NaN
# bx7               NaN         NaN
# bx8               NaN         NaN
# bx9               NaN         NaN
# bx10              NaN         NaN
# bx11              NaN         NaN
# bx12              NaN         NaN
# bx12-sbs          NaN         NaN
# bx13              NaN         NaN
# bx15              NaN         NaN
# bx16              NaN         NaN
# bx17              NaN         NaN
# bx18              NaN         NaN
# bx19              NaN         NaN
#
# [20 rows x 26 columns]

# %%
for route in routes:
    stripped_route = route.replace("-SBS", "").lower()
    miles = 0
    if route.lower() in profiles_df.index:
        miles = profiles_df.loc[route.lower(), "Length of Route (in miles)"]
    elif stripped_route in profiles_df.index:
        miles = profiles_df.loc[stripped_route, "Length of Route (in miles)"]
    routes_df.loc[route, "Length (miles)"] = miles
routes_df.head(20)
# Out:
#                                     End point 1  \
# Route
# Bx1                                   Riverdale
# Bx10                                  Riverdale
# Bx11                                Parkchester
# Bx12                                Pelham Pkwy
# Bx12-SBS                            Pelham Pkwy
# Bx13                   George Washington Bridge
# Bx15                              Fordham Plaza
# Bx16                                     Pelham
# Bx17                              Fordham Plaza
# Bx18      Morris Heights/High Bridge Circulator
# Bx19                        NY Botanical Garden
# Bx2                         Kingsbridge Heights
# Bx20                                  Riverdale
# Bx21                             Westchester Sq
# Bx22                               Bedford Park
# Bx24                               Country Club
# Bx26                       Co-op City Section 5
# Bx27                                 Clasons Pt
# Bx28                       Co-op City Section 5
# Bx29                                City Island
#
#                             End point 2  Length (miles)
# Route
# Bx1                          Mott Haven             8.8
# Bx10                            Norwood             7.4
# Bx11          Southern Blvd & GW Bridge             4.9
# Bx12                         Fordham Rd             8.1
# Bx12-SBS                     Fordham Rd             7.6
# Bx13                     Yankee Stadium             4.1
# Bx15                            The Hub             7.6
# Bx16                            Norwood             7.4
# Bx17                        Port Morris             5.7
# Bx18                               None             2.4
# Bx19                     Riverbank Park             6.8
# Bx2                          Mott Haven             8.0
# Bx20                             Inwood             3.7
# Bx21                         Mott Haven             6.9
# Bx22                        Castle Hill             6.6
# Bx24            Hutchinson Metro Center             4.5
# Bx26                       Bedford Park             6.1
# Bx27      West Farms Rd & Southern Blvd             3.6
# Bx28                     Fordham Center             9.7
# Bx29              Pelham Bay Pk Station             5.9

# %%
OUTPUT_FILE_ROUTES = "my_data/bus_route_endpoint_mileage.csv"
routes_df.to_csv(OUTPUT_FILE_ROUTES)

# %% [markdown]
# ## Get bus stops in every route

# %%
BUSTIME_URL = "https://bustime.mta.info"

stops_df = pd.DataFrame(columns=["Route", "Direction"])
stops_df = stops_df.set_index(["Route", "Direction"])

for route in tqdm(routes):
    query = f"{BUSTIME_URL}/m/index?q={route}"
    html = requests.get(query).text
    soup = BeautifulSoup(html, "html5lib")
    for div in soup.findAll("div", {"class": "directionForRoute"}):
        route_direction = div.find("p", {"class": "directionTitle"}).getText()
        route, _, direction  = route_direction.split(maxsplit=2)
        stop_num = 1
        for stop in div.findAll("li", {"class": ["start", "middle", "end"]}):
                stop_name = stop.find("a").getText()
                stops_df.loc[(route, direction), f"Stop {stop_num}"] = stop_name
                stop_num += 1
# Out:
# 100%|██████████| 242/242 [02:21<00:00,  1.71it/s]

# %%
stops_df.replace(np.nan, "", inplace=True)
stops_df.dropna(axis=1, how="all", inplace=True)
stops_df.head()
# Out:
#                                                           Stop 1  \
# Route Direction
# Bx1   MOTT HAVEN 138 ST via CONCOURSE      RIVERDALE AV/W 231 ST
#       RIVERDALE 231 ST via CONCOURSE         LINCOLN AV/E 137 ST
# Bx10  NORWOOD 205 ST STA                   RIVERDALE AV/W 263 ST
#       RIVERDALE 263 ST                   E 206 ST/ROCHAMBEAU AVE
# Bx11  WASHINGTON HEIGHTS G W BRIDGE    W FARMS RD/WESTCHESTER AV
#
#                                                                   Stop 2  \
# Route Direction
# Bx1   MOTT HAVEN 138 ST via CONCOURSE                W 231 ST/CORLEAR AV
#       RIVERDALE 231 ST via CONCOURSE            GRAND CONCOURSE/E 138 ST
# Bx10  NORWOOD 205 ST STA                           RIVERDALE AV/W 261 ST
#       RIVERDALE 263 ST                 E MOSHOLU PY N/VAN CORTLANDT AV E
# Bx11  WASHINGTON HEIGHTS G W BRIDGE                  W FARMS RD/E 167 ST
#
#                                                                  Stop 3  \
# Route Direction
# Bx1   MOTT HAVEN 138 ST via CONCOURSE                 W 231 ST/BROADWAY
#       RIVERDALE 231 ST via CONCOURSE           GRAND CONCOURSE/E 144 ST
# Bx10  NORWOOD 205 ST STA                          RIVERDALE AV/W 260 ST
#       RIVERDALE 263 ST                 VAN CORTLANDT AV E/ROCHAMBEAU AV
# Bx11  WASHINGTON HEIGHTS G W BRIDGE            W FARMS RD/LONGFELLOW AV
#
#                                                                Stop 4  \
# Route Direction
# Bx1   MOTT HAVEN 138 ST via CONCOURSE              W 231 ST/BAILEY AV
#       RIVERDALE 231 ST via CONCOURSE         GRAND CONCOURSE/E 149 ST
# Bx10  NORWOOD 205 ST STA                        RIVERDALE AV/W 259 ST
#       RIVERDALE 263 ST                 BAINBRIDGE AV/RESERVOIR OVAL E
# Bx11  WASHINGTON HEIGHTS G W BRIDGE            E 172 ST/LONGFELLOW AV
#
#                                                          Stop 5  \
# Route Direction
# Bx1   MOTT HAVEN 138 ST via CONCOURSE      HEATH AV/ALBANY CRES
#       RIVERDALE 231 ST via CONCOURSE   GRAND CONCOURSE/E 153 ST
# Bx10  NORWOOD 205 ST STA                  RIVERDALE AV/W 256 ST
#       RIVERDALE 263 ST                   BAINBRIDGE AV/E 210 ST
# Bx11  WASHINGTON HEIGHTS G W BRIDGE            E 172 ST/VYSE AV
#
#                                                             Stop 6  \
# Route Direction
# Bx1   MOTT HAVEN 138 ST via CONCOURSE           HEATH AV/SUMMIT PL
#       RIVERDALE 231 ST via CONCOURSE      GRAND CONCOURSE/E 156 ST
# Bx10  NORWOOD 205 ST STA                     RIVERDALE AV/W 254 ST
#       RIVERDALE 263 ST                 E GUN HILL RD/BAINBRIDGE AV
# Bx11  WASHINGTON HEIGHTS G W BRIDGE           E 172 ST/SOUTHERN BL
#
#                                                                Stop 7  \
# Route Direction
# Bx1   MOTT HAVEN 138 ST via CONCOURSE  SEDGWICK AV/FT INDEPENDENCE ST
#       RIVERDALE 231 ST via CONCOURSE         GRAND CONCOURSE/E 161 ST
# Bx10  NORWOOD 205 ST STA                  HENRY HUDSON PKY W/W 252 ST
#       RIVERDALE 263 ST                       E GUN HILL RD/DE KALB AV
# Bx11  WASHINGTON HEIGHTS G W BRIDGE            LOUIS NINE BL/E 170 ST
#
#                                                             Stop 8  \
# Route Direction
# Bx1   MOTT HAVEN 138 ST via CONCOURSE         SEDGWICK AV/GILES PL
#       RIVERDALE 231 ST via CONCOURSE      GRAND CONCOURSE/E 163 ST
# Bx10  NORWOOD 205 ST STA               HENRY HUDSON PKY W/W 249 ST
#       RIVERDALE 263 ST                    JEROME AV/E MOSHOLU PY N
# Bx11  WASHINGTON HEIGHTS G W BRIDGE        LOUIS NINE BL/BOSTON RD
#
#                                                              Stop 9  \
# Route Direction
# Bx1   MOTT HAVEN 138 ST via CONCOURSE    SEDGWICK AV/STEVENSON PL 1
#       RIVERDALE 231 ST via CONCOURSE       GRAND CONCOURSE/E 165 ST
# Bx10  NORWOOD 205 ST STA                HENRY HUDSON PKY W/W 246 ST
#       RIVERDALE 263 ST                           JEROME AV/E 205 ST
# Bx11  WASHINGTON HEIGHTS G W BRIDGE    CLAREMONT PKY/CROTONA PARK E
#
#                                                              Stop 10  ...  \
# Route Direction                                                       ...
# Bx1   MOTT HAVEN 138 ST via CONCOURSE     SEDGWICK AV/STEVENSON PL 2  ...
#       RIVERDALE 231 ST via CONCOURSE   GRAND CONCOURSE/MC CLELLAN ST  ...
# Bx10  NORWOOD 205 ST STA                 HENRY HUDSON PKY W/W 239 ST  ...
#       RIVERDALE 263 ST                          BEDFORD PK/JEROME AV  ...
# Bx11  WASHINGTON HEIGHTS G W BRIDGE         CLAREMONT PKY/CROTONA AV  ...
#
#                                       Stop 108 Stop 109 Stop 110 Stop 111  \
# Route Direction
# Bx1   MOTT HAVEN 138 ST via CONCOURSE
#       RIVERDALE 231 ST via CONCOURSE
# Bx10  NORWOOD 205 ST STA
#       RIVERDALE 263 ST
# Bx11  WASHINGTON HEIGHTS G W BRIDGE
#
#                                       Stop 112 Stop 113 Stop 114 Stop 115  \
# Route Direction
# Bx1   MOTT HAVEN 138 ST via CONCOURSE
#       RIVERDALE 231 ST via CONCOURSE
# Bx10  NORWOOD 205 ST STA
#       RIVERDALE 263 ST
# Bx11  WASHINGTON HEIGHTS G W BRIDGE
#
#                                       Stop 116 Stop 117
# Route Direction
# Bx1   MOTT HAVEN 138 ST via CONCOURSE
#       RIVERDALE 231 ST via CONCOURSE
# Bx10  NORWOOD 205 ST STA
#       RIVERDALE 263 ST
# Bx11  WASHINGTON HEIGHTS G W BRIDGE
#
# [5 rows x 117 columns]

# %%
OUTPUT_FILE_STOPS = "../../data/stops_by_route.csv"
stops_df.to_csv(OUTPUT_FILE_STOPS)
